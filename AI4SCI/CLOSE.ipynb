# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['agg.path.chunksize'] = 10000

# %%
filepath = 'cleaned.csv'
data = pd.read_csv(filepath)
data = data.sort_values('trade_date')
print(data.head())
print(data.shape)

sns.set_style("darkgrid")
plt.figure(figsize=(15, 9))
plt.plot(data[['close']])
plt.xticks(range(0, data.shape[0], 20), data['trade_date'].loc[::20], rotation=45)
plt.title("Stock Price", fontsize=18, fontweight='bold')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price (USD)', fontsize=18)
plt.show()
# Out:
#         Unnamed: 0  trade_date   open  close   high    low  change        vol
# 95947        95947    20050408  14.89  15.29  15.45  14.47    0.41   29931.95
# 23307        23307    20050408   2.98   3.03   3.04   2.94    0.04    8716.50
# 91757        91757    20050408   6.30   6.45   6.46   6.26    0.16   20664.51
# 120129      120129    20050408  12.52  12.37  12.80  12.13    0.27   19258.56
# 4588          4588    20050408   6.29   6.79   6.79   6.18    0.62  497164.01
# (761188, 8)
